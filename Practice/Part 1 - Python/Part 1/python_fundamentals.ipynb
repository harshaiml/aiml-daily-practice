# %%
f = open("sample.txt", "r")

data = f.read()
print(data)

f.close()
# Out:
# 123

# %%
f = open("sample.txt", "r")

data = f.readline()
print(data)

f.close()
# Out:
# 123

# %%
f = open("sample.txt", "r")

data = f.readline()
print(data)

data = f.readline()
print(data)

f.close()
# Out:
# 123

# %%
f = open("sample.txt", "w")

f.write("123")

f.close()

# %%
f = open("sample.txt")

print(f.read())

f.close()
# Out:
# 123

# %%
f = open("sample.txt", "a")

f.write("\nNew text being appended\n to the file")

f.close()

# %%
f = open("sample.txt", "r+")

f.write("123")
print(f.read())

f.close()
# Out:
# t which already
# exists in file.
# New text being appended
# to the file

# %%
f = open("sample.txt", "w+")

f.write("123")
print(f.read())

f.close()

# %%
with open("sample.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# We are using Python
# for programming.

# %%
with open("sample.txt", "r") as f:
    data = f.read()
    print(len(data))
# Out:
# 36

# %%
import os

os.remove("sample2.txt")

# %% [markdown]
# ### Word Search

# %%
data = True
line = 1
word = "Python"
with open("sample.txt", "r") as f:
    while data:
        data = f.readline()
        if(word in data):
            print(f"{word} found at line {line}")
            break
        line += 1
# Out:
# Python found at line 3

# %%
try:
    x = int(input("Enter x: "))
    ans = 10/x

except ZeroDivisionError:
    print(f"Divide by 0 is not allowed")

except ValueError:
    print(f"Invalid input")

else:
    print(f"ans = {ans}")

finally:
    print("Ennd of program")
# Out:
# ans = 0.625
# Ennd of program

# %%
squares = []

for i in range(6):
    squares.append(i*i)

print(squares)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
sq = [i*i for i in range(6)]
print(sq)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
sq = [i*i for i in range(6) if i%2 != 0]
print(sq)
# Out:
# [1, 9, 25]

# %%
nums = [-2, -3, 3, 4, -1, 7]

nums = [0 if val < 0 else val for val in nums]
print(nums)
# Out:
# [0, 0, 3, 4, 0, 7]

# %%
words = ["hello", "pyhton",]

words = [val.upper() for val in words]
print(words)
# Out:
# ['HELLO', 'PYHTON']

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"Hello, {name}, you are {age} year old!")
# Out:
# Hello, Harsh, you are 24 year old!

# %%
num1 = int(input("Enter your 1st number: "))
num2 = int(input("Enter your 2nd number: "))

sum = (num1 + num2)
diff = (num1 - num2)
pro = (num1 * num2)
quot = (num1 / num2)

print(f"Your 1st number is {num1}.")
print(f"Your 2nd number is {num2}.")

print(f"Sum is {sum}")
print(f"Difference is {diff}")
print(f"Product is {pro}")
print(f"Quotient is {quot}")
# Out:
# Your 1st number is 20.
# Your 2nd number is 30.
# Sum is 50
# Difference is -10
# Product is 600
# Quotient is 0.6666666666666666

# %%
num1 = int(input("Enter your 1st number: "))
num2 = int(input("Enter your 2nd number: "))
num3 = float(input("Enter your 3rd number: "))

num3 = int(num3)

avg = (num1 + num2 + num3)/3

print(f"Your 1st number is {num1}.")
print(f"Your 2nd number is {num2}.")
print(f"Your 3rd number is {num3}.")
print(f"Avrage of 3 numbers is {avg}.")
# Out:
# Your 1st number is 20.
# Your 2nd number is 30.
# Your 3rd number is 50.
# Avrage of 3 numbers is 33.333333333333336.

# %%
var = (input("Enter string: "))

var1 = int(var)
var2 = float(var)
var3 = str(var)

print(f"Value {var}",type(var1))
print(f"Value {var}",type(var2))
print(f"Value {var}",type(var3))
# Out:
# Value 45 <class 'int'>
# Value 45 <class 'float'>
# Value 45 <class 'str'>

# %%
x = 10 + 3 * 2 ** 2
print(f"Value of x is {x}")
# Out:
# Value of x is 22

# %%
num1 = int(input("Enter your first number:"))
num2 = int(input("Enter yurr second number:"))

# Step 1: store num1 in temp
temp = num1

# Step 2: assign num2 to num1
num1 = num2

# Step 3: assign temp (old num1) to num2
num2 = temp

print("After swapping:")
print("num1",num1)
print("num2",num2)
# Out:
# After swapping:
# num1 20
# num2 10

# %%
user = input("Enter celsius")
celsius = float(user)
fahrenheit = (celsius * (9/5))+32
print("Your temperature is",celsius)
print(f"FahrenheitTemp is = {fahrenheit}")
# Out:
# Your temperature is 30.0
# FahrenheitTemp is = 86.0

# %%
radius = float(input("Enter radius: "))
area = (3.14 * radius ** 2 )
print(f"Aare = {area}")
# Out:
# Aare = 314.0

# %%
p = (input("Enter your Principal value:"))
r = (input("Enter your rate of intrest:"))
t = (input("Enter your time:"))

p = float(p)
r = float(r)
t = float(t)

si = (p * r * t)/100

print(f"si = {si}")
# Out:
# si = 60.0

# %%
# Q10: Separate integer and fractional parts

# Take input
num = float(input("Enter a decimal number: "))

# Get integer part
integer_part = int(num)

# Get fractional part
fractional_part = num - integer_part

# Print results
print("Integer part:", integer_part)
print("Fractional part:", fractional_part)
# Out:
# Integer part: 45
# Fractional part: 0.7800000000000011
