# %% [markdown]
# ## Data_Collection_and_Cleaning

# %% [markdown]
# By the end of this session, learners will be able to:
# - Identify reliable data sources fo ML project
# - Collect data using open portals, APIs, and outliers
# - Handel missig values, categorical encoding, and outliers
# - Understand wht poor data cleaning breaks models
# - Explain data-cleaning decisions to business stakeholders
