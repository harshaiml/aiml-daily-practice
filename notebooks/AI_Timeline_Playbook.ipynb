# %%
#sample Program for rule filters

def rule_based_filter(text):
    return "with money" in text.lower()

def ai_based_filter(probability):
    return probability > 0.7


print("Rule Based result: ",rule_based_filter ("You WIN money now"))
# Out:
# Rule Based result:  False
